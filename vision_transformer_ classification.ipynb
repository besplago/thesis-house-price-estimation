[[255, 255, 255], [255, 255, 255], [255, 255,...
# 734            D  [[[255, 255, 255], [255, 255, 255], [255, 255,...
#
# [735 rows x 11 columns]

# %% [markdown]
# # Setting up splits

# %%
from sklearn.model_selection import train_test_split

# Split the data into train, validation and test sets with a 60-20-20 ratio
train_df, test_df = train_test_split(houses_df, test_size=0.2, random_state=0)
train_df, valid_df = train_test_split(train_df, test_size=0.20, random_state=0)

# %%
target_width = 448
target_height = 448

resize: bool = True
gray_scale: bool = False
threshhold: bool = True

train_images_RGB = preprocess_images(train_df, "image_floorplan", target_width, target_height, resize = resize, gray_scale = gray_scale, threshhold = threshhold)
validation_images_RGB = preprocess_images(valid_df, "image_floorplan", target_width, target_height, resize = resize, gray_scale = gray_scale, threshhold = threshhold)
test_images_RGB = preprocess_images(test_df, "image_floorplan", target_width, target_height, resize = resize, gray_scale = gray_scale, threshhold = threshhold)

print(f"Train set length:      {len(train_images_RGB)}")
print(f"Validation set length: {len(validation_images_RGB)}")
print(f"Test set length:       {len(test_images_RGB)}")

num_labels = 5

train_labels = prices_to_n_labels(houses_df['price'], train_df['price'], num_labels)
valid_labels = prices_to_n_labels(houses_df['price'], valid_df['price'], num_labels)
test_labels = prices_to_n_labels(houses_df['price'], test_df['price'], num_labels)

#Plot the first 5 images and their labels
fig, ax = plt.subplots(1, 5, figsize=(20, 20))
for i in range(5):
    ax[i].imshow(train_images_RGB[i])
    ax[i].set_title(f"Label: {(train_labels[i])}")
    ax[i].axis('off')
plt.show()
# Out:
# Train set length:      470
# Validation set length: 118
# Test set length:       147
# [2249800.0, 2995000.0, 3995000.0, 5696000.0]
# [2249800.0, 2995000.0, 3995000.0, 5696000.0]
# [2249800.0, 2995000.0, 3995000.0, 5696000.0]

# %% [markdown]
# # Pre-trained ViT

# %% [markdown]
# ## Model Fitting

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.activations import gelu
from vit_keras import vit
import tensorflow as tf
from multiprocessing import Process, Queue

def train_model(fine_tune_layers: int = 0):
    """
    Train a model with the vit architecture on the given data.
    
    Args:
        fine_tune_layers (int): Number of layers to fine-tune, counting from the top of the model.
    """
    set_gpu()
    
    # Load pre-trained VGG16 model (excluding top layers)
    base_model = vit.vit_b16(
        weights = 'imagenet21k+imagenet2012',
        image_size = (target_width, target_height),
        activation = 'softmax',
        pretrained = True, 
        include_top = False, 
        pretrained_top = False,
        classes = num_labels
    )

    # Freeze the pre-trained layers
    for layer in base_model.layers[:-fine_tune_layers] if fine_tune_layers > 0 else base_model.layers:
        layer.trainable = False

    # Add new top layers for regression
    model = Sequential([
        base_model,
        Flatten(),
        BatchNormalization(),
        Dense(11, activation = gelu),
        BatchNormalization(),
        Dense(num_labels, activation = 'softmax')
    ], name='vit-b16')

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()

    # Train the model with early stopping
    # early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    # history = model.fit(train_images_RGB, train_labels, validation_data=(validation_images_RGB, valid_labels), epochs=100, callbacks=[early_stopping])
    history = model.fit(train_images_RGB, train_labels, validation_data=(validation_images_RGB, valid_labels), epochs=100)

    model.save("./vit-b16_classification_model")

    # Plot the loss and accuracy
    fig, ax = plt.subplots(1, 2, figsize=(20, 5))
    ax[0].plot(history.history['loss'], label='loss')
    ax[0].plot(history.history['val_loss'], label='val_loss')
    ax[0].set_title('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')
    ax[0].legend()
    ax[1].plot(history.history['accuracy'], label='accuracy')
    ax[1].plot(history.history['val_accuracy'], label='val_accuracy')
    ax[1].set_title('Accuracy')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Accuracy')
    ax[1].legend()
    plt.show()

p = Process(target=train_model, args=(0,))
p.start()
p.join()
# Out:
# /home/besplago/.pyenv/versions/penv/lib/python3.11/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2024-03-14 10:31:40.543669: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.564312: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.564410: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.567363: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.567561: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.567641: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 1 Physical GPUs, 1 Logical GPU
# 2024-03-14 10:31:40.762436: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.762616: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.762635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-14 10:31:40.762693: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 10:31:40.762718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# /home/besplago/.pyenv/versions/penv/lib/python3.11/site-packages/vit_keras/utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 28, 28
#   warnings.warn(
# Model: "vit-b16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit-b16 (Functional)        (None, 768)               86250240
#
#  flatten (Flatten)           (None, 768)               0
#
#  batch_normalization (Batch  (None, 768)               3072
#  Normalization)
#
#  dense (Dense)               (None, 11)                8459
#
#  batch_normalization_1 (Bat  (None, 11)                44
#  chNormalization)
#
#  dense_1 (Dense)             (None, 5)                 60
#
# =================================================================
# Total params: 86261875 (329.06 MB)
# Trainable params: 10077 (39.36 KB)
# Non-trainable params: 86251798 (329.02 MB)
# _________________________________________________________________
# Epoch 1/100
# 2024-03-14 10:32:02.311983: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-03-14 10:32:02.583874: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-14 10:32:03.943908: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-14 10:32:07.057810: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fea04168df0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-14 10:32:07.057850: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2024-03-14 10:32:07.062487: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710408727.136471   46177 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 15/15 [==============================] - 59s 3s/step - loss: 2.0077 - accuracy: 0.2213 - val_loss: 1.6873 - val_accuracy: 0.2373
# Epoch 2/100
# 15/15 [==============================] - 37s 3s/step - loss: 1.8989 - accuracy: 0.2319 - val_loss: 1.6356 - val_accuracy: 0.2288
# Epoch 3/100
# 15/15 [==============================] - 38s 3s/step - loss: 1.9636 - accuracy: 0.2213 - val_loss: 1.6255 - val_accuracy: 0.2034
# Epoch 4/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.8799 - accuracy: 0.2362 - val_loss: 1.6218 - val_accuracy: 0.2458
# Epoch 5/100
# 15/15 [==============================] - 47s 3s/step - loss: 1.7719 - accuracy: 0.2426 - val_loss: 1.6070 - val_accuracy: 0.2119
# Epoch 6/100
# 15/15 [==============================] - 47s 3s/step - loss: 1.7347 - accuracy: 0.2489 - val_loss: 1.5854 - val_accuracy: 0.2627
# Epoch 7/100
# 15/15 [==============================] - 46s 3s/step - loss: 1.6984 - accuracy: 0.2787 - val_loss: 1.5754 - val_accuracy: 0.2627
# Epoch 8/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.7069 - accuracy: 0.2574 - val_loss: 1.5656 - val_accuracy: 0.2966
# Epoch 9/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.6509 - accuracy: 0.2702 - val_loss: 1.5625 - val_accuracy: 0.2966
# Epoch 10/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.6374 - accuracy: 0.2745 - val_loss: 1.5596 - val_accuracy: 0.2627
# Epoch 11/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.6686 - accuracy: 0.2723 - val_loss: 1.5673 - val_accuracy: 0.2966
# Epoch 12/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5982 - accuracy: 0.2936 - val_loss: 1.5761 - val_accuracy: 0.2797
# Epoch 13/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.6288 - accuracy: 0.2766 - val_loss: 1.5676 - val_accuracy: 0.2712
# Epoch 14/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.6001 - accuracy: 0.3213 - val_loss: 1.5681 - val_accuracy: 0.2712
# Epoch 15/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5331 - accuracy: 0.3383 - val_loss: 1.5756 - val_accuracy: 0.2881
# Epoch 16/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5873 - accuracy: 0.2894 - val_loss: 1.5734 - val_accuracy: 0.2712
# Epoch 17/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5535 - accuracy: 0.3128 - val_loss: 1.5722 - val_accuracy: 0.2542
# Epoch 18/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5522 - accuracy: 0.2979 - val_loss: 1.5659 - val_accuracy: 0.2712
# Epoch 19/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5532 - accuracy: 0.2894 - val_loss: 1.5719 - val_accuracy: 0.2966
# Epoch 20/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5594 - accuracy: 0.3064 - val_loss: 1.5760 - val_accuracy: 0.2797
# Epoch 21/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5585 - accuracy: 0.3319 - val_loss: 1.5907 - val_accuracy: 0.2881
# Epoch 22/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5487 - accuracy: 0.3128 - val_loss: 1.5949 - val_accuracy: 0.2966
# Epoch 23/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5146 - accuracy: 0.3532 - val_loss: 1.5929 - val_accuracy: 0.3051
# Epoch 24/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.4956 - accuracy: 0.3383 - val_loss: 1.5887 - val_accuracy: 0.2881
# Epoch 25/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5098 - accuracy: 0.3213 - val_loss: 1.5918 - val_accuracy: 0.2966
# Epoch 26/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.5199 - accuracy: 0.3319 - val_loss: 1.5935 - val_accuracy: 0.2797
# Epoch 27/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.5388 - accuracy: 0.3043 - val_loss: 1.5928 - val_accuracy: 0.2881
# Epoch 28/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.4978 - accuracy: 0.3170 - val_loss: 1.5880 - val_accuracy: 0.2797
# Epoch 29/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.4986 - accuracy: 0.3383 - val_loss: 1.5907 - val_accuracy: 0.2627
# Epoch 30/100
# 15/15 [==============================] - 38s 3s/step - loss: 1.4659 - accuracy: 0.3574 - val_loss: 1.5964 - val_accuracy: 0.2797
# Epoch 31/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.5018 - accuracy: 0.3553 - val_loss: 1.5830 - val_accuracy: 0.2712
# Epoch 32/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.4879 - accuracy: 0.3681 - val_loss: 1.5812 - val_accuracy: 0.2712
# Epoch 33/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.4661 - accuracy: 0.3319 - val_loss: 1.5814 - val_accuracy: 0.2712
# Epoch 34/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.4955 - accuracy: 0.3298 - val_loss: 1.5705 - val_accuracy: 0.2712
# Epoch 35/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4828 - accuracy: 0.3234 - val_loss: 1.5689 - val_accuracy: 0.2881
# Epoch 36/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4690 - accuracy: 0.3574 - val_loss: 1.5660 - val_accuracy: 0.2881
# Epoch 37/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4265 - accuracy: 0.3702 - val_loss: 1.5732 - val_accuracy: 0.3051
# Epoch 38/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4511 - accuracy: 0.3979 - val_loss: 1.5746 - val_accuracy: 0.3051
# Epoch 39/100
# 15/15 [==============================] - 38s 3s/step - loss: 1.4585 - accuracy: 0.3766 - val_loss: 1.5779 - val_accuracy: 0.3136
# Epoch 40/100
# 15/15 [==============================] - 38s 3s/step - loss: 1.4738 - accuracy: 0.3489 - val_loss: 1.5635 - val_accuracy: 0.2966
# Epoch 41/100
# 15/15 [==============================] - 38s 3s/step - loss: 1.4498 - accuracy: 0.4000 - val_loss: 1.5554 - val_accuracy: 0.2966
# Epoch 42/100
# 15/15 [==============================] - 38s 3s/step - loss: 1.4479 - accuracy: 0.3915 - val_loss: 1.5548 - val_accuracy: 0.3051
# Epoch 43/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.4505 - accuracy: 0.3702 - val_loss: 1.5576 - val_accuracy: 0.3051
# Epoch 44/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4598 - accuracy: 0.3574 - val_loss: 1.5582 - val_accuracy: 0.3220
# Epoch 45/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4588 - accuracy: 0.3766 - val_loss: 1.5617 - val_accuracy: 0.2881
# Epoch 46/100
# 15/15 [==============================] - 39s 3s/step - loss: 1.4322 - accuracy: 0.3702 - val_loss: 1.5653 - val_accuracy: 0.3051
# Epoch 47/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4300 - accuracy: 0.3851 - val_loss: 1.5577 - val_accuracy: 0.3136
# Epoch 48/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4390 - accuracy: 0.3915 - val_loss: 1.5577 - val_accuracy: 0.2966
# Epoch 49/100
# 15/15 [==============================] - 40s 3s/step - loss: 1.4331 - accuracy: 0.4021 - val_loss: 1.5554 - val_accuracy: 0.2797
# Epoch 50/100
# 15/15 [==============================] - 45s 3s/step - loss: 1.4366 - accuracy: 0.3830 - val_loss: 1.5525 - val_accuracy: 0.3051
# Epoch 51/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.4239 - accuracy: 0.3681 - val_loss: 1.5554 - val_accuracy: 0.2966
# Epoch 52/100
# 15/15 [==============================] - 45s 3s/step - loss: 1.4420 - accuracy: 0.3894 - val_loss: 1.5540 - val_accuracy: 0.2966
# Epoch 53/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.4197 - accuracy: 0.4085 - val_loss: 1.5580 - val_accuracy: 0.2712
# Epoch 54/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.4092 - accuracy: 0.4149 - val_loss: 1.5615 - val_accuracy: 0.2881
# Epoch 55/100
# 15/15 [==============================] - 41s 3s/step - loss: 1.4081 - accuracy: 0.4149 - val_loss: 1.5646 - val_accuracy: 0.3051
# Epoch 56/100
# 15/15 [==============================] - 41s 3s/step - loss: 1.4341 - accuracy: 0.3979 - val_loss: 1.5645 - val_accuracy: 0.2881
# Epoch 57/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.4059 - accuracy: 0.4064 - val_loss: 1.5643 - val_accuracy: 0.2966
# Epoch 58/100
# 15/15 [==============================] - 43s 3s/step - loss: 1.3869 - accuracy: 0.4340 - val_loss: 1.5611 - val_accuracy: 0.2797
# Epoch 59/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3929 - accuracy: 0.4043 - val_loss: 1.5609 - val_accuracy: 0.2797
# Epoch 60/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3809 - accuracy: 0.4191 - val_loss: 1.5560 - val_accuracy: 0.2881
# Epoch 61/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.4104 - accuracy: 0.3851 - val_loss: 1.5493 - val_accuracy: 0.3136
# Epoch 62/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.4086 - accuracy: 0.3830 - val_loss: 1.5555 - val_accuracy: 0.3051
# Epoch 63/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.4050 - accuracy: 0.3766 - val_loss: 1.5568 - val_accuracy: 0.3051
# Epoch 64/100
# 15/15 [==============================] - 43s 3s/step - loss: 1.3755 - accuracy: 0.4106 - val_loss: 1.5595 - val_accuracy: 0.3051
# Epoch 65/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.3617 - accuracy: 0.4021 - val_loss: 1.5570 - val_accuracy: 0.2966
# Epoch 66/100
# 15/15 [==============================] - 44s 3s/step - loss: 1.3963 - accuracy: 0.3894 - val_loss: 1.5586 - val_accuracy: 0.2966
# Epoch 67/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3499 - accuracy: 0.4426 - val_loss: 1.5625 - val_accuracy: 0.3051
# Epoch 68/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3858 - accuracy: 0.4149 - val_loss: 1.5569 - val_accuracy: 0.2881
# Epoch 69/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.4126 - accuracy: 0.3745 - val_loss: 1.5599 - val_accuracy: 0.3051
# Epoch 70/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3710 - accuracy: 0.4234 - val_loss: 1.5639 - val_accuracy: 0.3051
# Epoch 71/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.4250 - accuracy: 0.3766 - val_loss: 1.5712 - val_accuracy: 0.3305
# Epoch 72/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3784 - accuracy: 0.3915 - val_loss: 1.5720 - val_accuracy: 0.3136
# Epoch 73/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3469 - accuracy: 0.4447 - val_loss: 1.5647 - val_accuracy: 0.3305
# Epoch 74/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3662 - accuracy: 0.4085 - val_loss: 1.5731 - val_accuracy: 0.3305
# Epoch 75/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3920 - accuracy: 0.4106 - val_loss: 1.5740 - val_accuracy: 0.3475
# Epoch 76/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3613 - accuracy: 0.4383 - val_loss: 1.5771 - val_accuracy: 0.3051
# Epoch 77/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3514 - accuracy: 0.4340 - val_loss: 1.5719 - val_accuracy: 0.3051
# Epoch 78/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3511 - accuracy: 0.4574 - val_loss: 1.5749 - val_accuracy: 0.3051
# Epoch 79/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3330 - accuracy: 0.4553 - val_loss: 1.5736 - val_accuracy: 0.2797
# Epoch 80/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3458 - accuracy: 0.3979 - val_loss: 1.5813 - val_accuracy: 0.3051
# Epoch 81/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3456 - accuracy: 0.4085 - val_loss: 1.5814 - val_accuracy: 0.2797
# Epoch 82/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3564 - accuracy: 0.4106 - val_loss: 1.5784 - val_accuracy: 0.3051
# Epoch 83/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3325 - accuracy: 0.4362 - val_loss: 1.5862 - val_accuracy: 0.2881
# Epoch 84/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3234 - accuracy: 0.4489 - val_loss: 1.5850 - val_accuracy: 0.2966
# Epoch 85/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3874 - accuracy: 0.4000 - val_loss: 1.5887 - val_accuracy: 0.3051
# Epoch 86/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3496 - accuracy: 0.4277 - val_loss: 1.5896 - val_accuracy: 0.2966
# Epoch 87/100
# 15/15 [==============================] - 41s 3s/step - loss: 1.3522 - accuracy: 0.4043 - val_loss: 1.5929 - val_accuracy: 0.2966
# Epoch 88/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3947 - accuracy: 0.4064 - val_loss: 1.5922 - val_accuracy: 0.2712
# Epoch 89/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3600 - accuracy: 0.4319 - val_loss: 1.5975 - val_accuracy: 0.2627
# Epoch 90/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3124 - accuracy: 0.4532 - val_loss: 1.6069 - val_accuracy: 0.2627
# Epoch 91/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3320 - accuracy: 0.4298 - val_loss: 1.6011 - val_accuracy: 0.2542
# Epoch 92/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.2957 - accuracy: 0.4511 - val_loss: 1.5887 - val_accuracy: 0.2881
# Epoch 93/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.2853 - accuracy: 0.4702 - val_loss: 1.5957 - val_accuracy: 0.2797
# Epoch 94/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3003 - accuracy: 0.4574 - val_loss: 1.5936 - val_accuracy: 0.2966
# Epoch 95/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3434 - accuracy: 0.4404 - val_loss: 1.5925 - val_accuracy: 0.2966
# Epoch 96/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3091 - accuracy: 0.4660 - val_loss: 1.5978 - val_accuracy: 0.2881
# Epoch 97/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3557 - accuracy: 0.4404 - val_loss: 1.5966 - val_accuracy: 0.2966
# Epoch 98/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3460 - accuracy: 0.4170 - val_loss: 1.5959 - val_accuracy: 0.3305
# Epoch 99/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3240 - accuracy: 0.4511 - val_loss: 1.5926 - val_accuracy: 0.3475
# Epoch 100/100
# 15/15 [==============================] - 42s 3s/step - loss: 1.3022 - accuracy: 0.4660 - val_loss: 1.5967 - val_accuracy: 0.3220
# WARNING:absl:`vit-b16_input` is not a valid tf.function parameter name. Sanitizing to `vit_b16_input`.
# WARNING:absl:`vit-b16_input` is not a valid tf.function parameter name. Sanitizing to `vit_b16_input`.
# WARNING:absl:`vit-b16_input` is not a valid tf.function parameter name. Sanitizing to `vit_b16_input`.
# INFO:tensorflow:Assets written to: ./vit-b16_classification_model/assets
# INFO:tensorflow:Assets written to: ./vit-b16_classification_model/assets

# %%
# vit-b32
# model = Sequential([
#     base_model,
#     Flatten(),
#     BatchNormalization(),
#     Dense(num_labels, activation='softmax')
# ], name='vit-b32')
# learning_rate = 0.0001
# epochs = 100
# results:
#               precision    recall  f1-score   support

#            0       0.55      0.43      0.48        70
#            1       0.57      0.68      0.62        77

#     accuracy                           0.56       147
#    macro avg       0.56      0.55      0.55       147
# weighted avg       0.56      0.56      0.55       147

# model = Sequential([
#     base_model,
#     Flatten(),
#     BatchNormalization(),
#     Dense(11, activation = gelu),
#     BatchNormalization(),
#     Dense(num_labels, activation = 'softmax')
# ], name='vit-b32')
# # learning_rate = 0.0001
# # epochs = 100
# # results:
# #               precision    recall  f1-score   support

# #            0       0.55      0.80      0.65        70
# #            1       0.69      0.40      0.51        77

# #     accuracy                           0.59       147
# #    macro avg       0.62      0.60      0.58       147
# # weighted avg       0.62      0.59      0.58       147

# # learning_rate = 0.0001
# # epochs = 1000
# # results:
# #               precision    recall  f1-score   support

# #            0       0.59      0.47      0.52        70
# #            1       0.59      0.70      0.64        77

# #     accuracy                           0.59       147
# #    macro avg       0.59      0.59      0.58       147
# # weighted avg       0.59      0.59      0.59       147

# # learning_rate = 0.001
# # epochs = 100
# # results:
# #               precision    recall  f1-score   support

# #            0       0.61      0.51      0.56        70
# #            1       0.61      0.70      0.65        77

# #     accuracy                           0.61       147
# #    macro avg       0.61      0.61      0.61       147
# # weighted avg       0.61      0.61      0.61       147

# vit-b16
# model = Sequential([
#     base_model,
#     Flatten(),
#     BatchNormalization(),
#     Dense(11, activation = gelu),
#     BatchNormalization(),
#     Dense(num_labels, activation = 'softmax')
# ], name='vit-b16')
# # learning_rate = 0.001
# # epochs = 1000
# # results:
# #               precision    recall  f1-score   support

# #            0       0.66      0.56      0.60        70
# #            1       0.65      0.74      0.69        77

# #     accuracy                           0.65       147
# #    macro avg       0.65      0.65      0.65       147
# # weighted avg       0.65      0.65      0.65       147

# # labels = 5
# # learning_rate = 0.001
# # epochs = 100
# # results:
# #               precision    recall  f1-score   support

# #            0       0.22      0.23      0.23        26
# #            1       0.30      0.21      0.24        29
# #            2       0.38      0.50      0.43        26
# #            3       0.23      0.28      0.25        29
# #            4       0.55      0.46      0.50        37

# #     accuracy                           0.34       147
# #    macro avg       0.34      0.33      0.33       147
# # weighted avg       0.35      0.34      0.34       147

# %% [markdown]
# ## Model Evaluation

# %%
def evaluate_model(queue: Queue):
    set_gpu()
    
    # Evaluate the model
    loaded_model = tf.keras.models.load_model("./vit-b16_classification_model")
    loaded_model.evaluate(test_images_RGB, test_labels)
    predictions: np.ndarray = loaded_model.predict(test_images_RGB)
    
    queue.put(predictions)

queue = Queue()
p = Process(target=evaluate_model, args=(queue,))
p.start()
p.join()

if queue.empty():
    raise ValueError("Nothing was returned from the process")
predictions = queue.get()
real_labels = np.argmax(test_labels, axis=1)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 1 Physical GPUs, 1 Logical GPU
# 2024-03-14 14:11:49.254276: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.293252: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.293374: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.297907: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.298184: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.298283: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.427973: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.428266: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.428316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-14 14:11:49.428420: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-14 14:11:49.428481: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2024-03-14 14:12:27.099565: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-03-14 14:12:27.175555: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-14 14:12:27.278425: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 5/5 [==============================] - 14s 2s/step - loss: 1.5783 - accuracy: 0.3401
# 5/5 [==============================] - 12s 2s/step

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve

# Plot the predictions
plt.figure(figsize=(10, 10))
for i, (image, label, prediction) in enumerate(zip(test_images_RGB[:9], real_labels[:9], predicted_labels[:9])):
    plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(f"Real: {label}\nPredicted: {prediction}")
    plt.axis("off")
plt.show()

# Plot the confusion matrix
confusion = confusion_matrix(real_labels, predicted_labels)
plt.figure(figsize=(10, 10))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Real')
plt.title('Confusion Matrix')
plt.show()

# Plot the classification report
print(classification_report(real_labels, predicted_labels))

# Plot the ROC curve (only if there are 2 classes)
if num_labels == 2:
    fpr, tpr, thresholds = roc_curve(real_labels, predicted_labels)
    plt.figure(figsize=(10, 10))
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.23      0.23        26
#            1       0.30      0.21      0.24        29
#            2       0.38      0.50      0.43        26
#            3       0.23      0.28      0.25        29
#            4       0.55      0.46      0.50        37
#
#     accuracy                           0.34       147
#    macro avg       0.34      0.33      0.33       147
# weighted avg       0.35      0.34      0.34       147

# %%
def evaluate_majority_naive_model():
    """This model simply predicts the majority class"""
    majority_class = np.argmax(np.mean(train_labels, axis=0))
    naive_predictions = np.full((len(test_labels), num_labels), 0)
    naive_predictions[:, majority_class] = 1
    return naive_predictions

def evaluate_random_naive_model():
    """This model simply predicts a random class"""
    naive_predictions = np.zeros((len(test_labels), num_labels))
    for i in range(len(test_labels)):
        naive_predictions[i, np.random.randint(0, num_labels)] = 1
    return naive_predictions

naive_predictions = evaluate_random_naive_model()
naive_predicted_labels = np.argmax(naive_predictions, axis=1)

# %%
# Plot the naive confusion matrix
naive_confusion = confusion_matrix(real_labels, naive_predicted_labels)
plt.figure(figsize=(10, 10))
sns.heatmap(naive_confusion, annot=True, fmt='g', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Real')
plt.title('Naive Confusion Matrix')
plt.show()

# Plot the naive classification report
print(classification_report(real_labels, naive_predicted_labels))

# Plot the naive ROC curve
if num_labels == 2:
    fpr, tpr, thresholds = roc_curve(real_labels, naive_predicted_labels)
    plt.figure(figsize=(10, 10))
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Naive ROC Curve')
    plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.27      0.28        26
#            1       0.12      0.14      0.13        29
#            2       0.18      0.19      0.19        26
#            3       0.31      0.31      0.31        29
#            4       0.21      0.19      0.20        37
#
#     accuracy                           0.22       147
#    macro avg       0.22      0.22      0.22       147
# weighted avg       0.22      0.22      0.22       147
